# %%
# !pip install xarray
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.9/870.9 kB 3.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from kedro.extras.datasets.xarray.netcdf import NetCDFDataSet

# %%
data.t
# Out:
# <bound method Dataset.to_netcdf of <xarray.Dataset>
# Dimensions:  (x: 4, y: 5)
# Coordinates:
#   * x        (x) int64 10 20 30 40
#   * y        (y) datetime64[ns] 2000-01-01 2000-01-02 ... 2000-01-04 2000-01-05
#     z        (x) <U1 'a' 'b' 'c' 'd'
# Data variables:
#     foo      (x, y) float64 0.2553 0.1788 0.05325 ... 0.5846 0.9723 0.8543>

# %%
 from kedro.extras.datasets.xarray.netcdf import NetCDFDataSet
 import numpy as np
 import pandas as pd
 import xarray as xr

 data = xr.Dataset(
     {"foo": (("x", "y"), np.random.rand(4, 5))},
     coords={
         "x": [10, 20, 30, 40],
         "y": pd.date_range("2000-01-01", periods=5),
         "z": ("x", list("abcd")),
     },
 )

 # data_set = GenericDataSet(filepath="gcs://bucket/test.nc")
 data_set = NetCDFDataSet(filepath="test.nc")
 data_set.save(data)
 reloaded = data_set.load()
 assert data.equals(reloaded)

# %%
data_set.
# Out:
# <xarray.Dataset>
# Dimensions:  (y: 5, x: 4)
# Coordinates:
#   * y        (y) datetime64[ns] 2000-01-01 2000-01-02 ... 2000-01-04 2000-01-05
#     z        (x) object ...
#   * x        (x) int32 10 20 30 40
# Data variables:
#     foo      (x, y) float64 ...

# %%
data.to_netcdf("test.nc")

# %%
NetCDFDataSet(filepath='test.nc').load()
# Out:
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │ /Users/Nok_Lam_Chan/GitHub/kedro/kedro/io/core.py:182 in load                             │
# │                                                                                           │
# │   179 │   │   self._logger.debug("Loading %s", str(self))                                 │
# │   180 │   │                                                                               │
# │   181 │   │   try:                                                                        │
# │ ❱ 182 │   │   │   return self._load()                                                     │
# │   183 │   │   except DataSetError:                                                        │
# │   184 │   │   │   raise                                                                   │
# │   185 │   │   except Exception as exc:                                                    │
# ...
